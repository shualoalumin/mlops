# %% [markdown]
# # 1) 라이브러리 임포트 / Import Libraries
# **[KOR]** 이 셀에서는 전체 파이프라인에 필요한 라이브러리를 임포트합니다.
# **[ENG]** This cell imports all libraries required for the entire pipeline.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Hugging Face 관련 라이브러리 / Hugging Face libraries
from transformers import (ViTImageProcessor, ViTForImageClassification,
                          TFViTModel, create_optimizer, TrainingArguments, Trainer,
                          DefaultDataCollator)

# W&B / Weights & Biases
import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

# 기타 / Others
import numpy as np
import os
from datasets import Dataset
# Out:
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 2) W&B 프로젝트 초기화 / Initialize W&B
# **[KOR]** 여기서는 W&B 프로젝트를 초기화합니다. 원하는 프로젝트 이름과 실험명을 지정할 수 있습니다.
# **[ENG]** Here, we initialize a W&B project. Customize the project name and run name as desired.

# %%
wandb.init(
    project="ViT_vs_CNN_flowers", 
)
# Out:
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/f7xahaql?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# # 3) 데이터셋 로드 및 전처리 / Load and Preprocess the Dataset
# **[KOR]** `tf_flowers` 데이터셋을 가져와서 (image, label) 쌍으로 분할하고, 224×224로 리사이즈 및 0~1 범위 정규화 후 배치 형태로 준비합니다.
# **[ENG]** Load the `tf_flowers` dataset, split it into (image, label) pairs, resize to 224×224, normalize to [0,1], and prepare it in batches.

# %%
# Load dataset
dataset, info = tfds.load("tf_flowers", as_supervised=True, with_info=True)
num_classes = info.features['label'].num_classes
total_examples = info.splits['train'].num_examples

train_size = int(total_examples * 0.8)
val_size = int(total_examples * 0.1)
test_size = int(total_examples * 0.1)

# Preprocessing function
def format_image(image, label, img_size=224):
    image = tf.image.resize(image, (img_size, img_size))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

ds_all = dataset['train'].map(lambda x, y: format_image(x, y, 224))

# Split dataset
train_ds = ds_all.take(train_size)
val_ds = ds_all.skip(train_size).take(val_size)
test_ds = ds_all.skip(train_size + val_size).take(test_size)

batch_size = 32
train_batches = train_ds.shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
val_batches = val_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
test_batches = test_ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

print(f"Number of classes: {num_classes}")
print(f"Total samples: {total_examples}")
# Out:
# Number of classes: 5
# Total samples: 3670

# %% [markdown]
# # 4) 간단 CNN 모델 정의 / Define a Simple CNN Model
# **[KOR]** 전통적인 CNN 모델과 비교하기 위해, 간단한 Conv-BN-MaxPool 구조의 CNN 모델을 정의합니다.
# **[ENG]** Define a simple CNN model (Conv-BN-MaxPool architecture) for comparison with the ViT model.

# %%
def create_simple_cnn(num_classes):
    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = tf.keras.layers.Conv2D(32, 3, activation='relu')(inputs)
    x = tf.keras.layers.MaxPool2D()(x)
    x = tf.keras.layers.Conv2D(64, 3, activation='relu')(x)
    x = tf.keras.layers.MaxPool2D()(x)
    x = tf.keras.layers.Conv2D(128, 3, activation='relu')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs)
    return model

# %% [markdown]
# # 5) CNN 모델 훈련 / Train the CNN Model
# **[KOR]** 간단 CNN 모델을 학습시키고 W&B에 로깅합니다. CNN 성능을 파악한 뒤, 이후 ViT와 비교할 수 있습니다.
# **[ENG]** Train the simple CNN model and log metrics to W&B. We can then compare its performance to the ViT model.

# %%
# CNN model
cnn_model = create_simple_cnn(num_classes)

wandb.init(
    project="ViT_vs_CNN_flowers", 
    name="CNN_flowers_run", 
    reinit=True
)

cnn_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_model.fit(
    train_batches,
    validation_data=val_batches,
    epochs=3,  # 예시로 3 epoch
    callbacks=[WandbMetricsLogger(log_freq="epoch"),WandbModelCheckpoint("model_checkpoint.keras")]
)

# Evaluate on test set
cnn_eval = cnn_model.evaluate(test_batches)
print("CNN Test Evaluation:", cnn_eval)
wandb.finish()
# Out:
#  View run <strong style="color:#cdcd00">CNN_flowers_run</strong> at: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/pccd4qb0' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/pccd4qb0</a><br> View project at: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250125_035742-pccd4qb0\logs</code>
# Tracking run with wandb version 0.19.4
# Run data is saved locally in <code>c:\Users\User\Documents\GitHub\mlops\wandb\run-20250125_035807-cpmagrre</code>
# Syncing run <strong><a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/cpmagrre' target="_blank">CNN_flowers_run</a></strong> to <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers</a>
#  View run at <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/cpmagrre' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/cpmagrre</a>
# Epoch 1/3
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3:53 3s/step - accuracy: 0.2500 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 43s 485ms/step - accuracy: 0.2188 - loss: 1.608 ━━━━━━━━━━━━━━━━━━━━ 42s 473ms/step - accuracy: 0.2118 - loss: 1.608 ━━━━━━━━━━━━━━━━━━━━ 40s 459ms/step - accuracy: 0.2116 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 39s 457ms/step - accuracy: 0.2105 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 38s 453ms/step - accuracy: 0.2076 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 38s 447ms/step - accuracy: 0.2060 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 36s 439ms/step - accuracy: 0.2061 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 35s 433ms/step - accuracy: 0.2079 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 35s 430ms/step - accuracy: 0.2105 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 34s 426ms/step - accuracy: 0.2126 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 33s 424ms/step - accuracy: 0.2148 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 33s 422ms/step - accuracy: 0.2175 - loss: 1.607 ━━━━━━━━━━━━━━━━━━━━ 32s 419ms/step - accuracy: 0.2195 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 32s 420ms/step - accuracy: 0.2217 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 31s 418ms/step - accuracy: 0.2237 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 31s 418ms/step - accuracy: 0.2255 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 31s 419ms/step - accuracy: 0.2270 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 30s 419ms/step - accuracy: 0.2287 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 30s 419ms/step - accuracy: 0.2302 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 29s 418ms/step - accuracy: 0.2317 - loss: 1.606 ━━━━━━━━━━━━━━━━━━━━ 29s 417ms/step - accuracy: 0.2330 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 28s 416ms/step - accuracy: 0.2341 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 28s 415ms/step - accuracy: 0.2352 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 27s 416ms/step - accuracy: 0.2363 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 27s 415ms/step - accuracy: 0.2372 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 26s 415ms/step - accuracy: 0.2381 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 26s 414ms/step - accuracy: 0.2390 - loss: 1.605 ━━━━━━━━━━━━━━━━━━━━ 26s 414ms/step - accuracy: 0.2399 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 25s 414ms/step - accuracy: 0.2408 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 25s 414ms/step - accuracy: 0.2416 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 24s 414ms/step - accuracy: 0.2423 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 24s 415ms/step - accuracy: 0.2432 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 24s 415ms/step - accuracy: 0.2441 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.2449 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.2458 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.2466 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.2474 - loss: 1.604 ━━━━━━━━━━━━━━━━━━━━ 22s 416ms/step - accuracy: 0.2482 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - accuracy: 0.2490 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - accuracy: 0.2498 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 20s 416ms/step - accuracy: 0.2504 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 20s 416ms/step - accuracy: 0.2510 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 19s 417ms/step - accuracy: 0.2515 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 19s 417ms/step - accuracy: 0.2520 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 19s 417ms/step - accuracy: 0.2525 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 18s 418ms/step - accuracy: 0.2529 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 18s 419ms/step - accuracy: 0.2534 - loss: 1.603 ━━━━━━━━━━━━━━━━━━━━ 18s 419ms/step - accuracy: 0.2539 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 17s 419ms/step - accuracy: 0.2544 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 17s 419ms/step - accuracy: 0.2549 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 16s 419ms/step - accuracy: 0.2554 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 16s 419ms/step - accuracy: 0.2560 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 15s 418ms/step - accuracy: 0.2565 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 15s 419ms/step - accuracy: 0.2571 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 15s 419ms/step - accuracy: 0.2577 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 14s 419ms/step - accuracy: 0.2583 - loss: 1.602 ━━━━━━━━━━━━━━━━━━━━ 14s 419ms/step - accuracy: 0.2588 - loss:  ...
# Epoch 2/3
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 58s 644ms/step - accuracy: 0.4062 - loss: 1.478 ━━━━━━━━━━━━━━━━━━━━ 41s 464ms/step - accuracy: 0.4297 - loss: 1.490 ━━━━━━━━━━━━━━━━━━━━ 39s 443ms/step - accuracy: 0.4358 - loss: 1.494 ━━━━━━━━━━━━━━━━━━━━ 38s 440ms/step - accuracy: 0.4303 - loss: 1.497 ━━━━━━━━━━━━━━━━━━━━ 37s 434ms/step - accuracy: 0.4268 - loss: 1.499 ━━━━━━━━━━━━━━━━━━━━ 37s 434ms/step - accuracy: 0.4199 - loss: 1.502 ━━━━━━━━━━━━━━━━━━━━ 37s 438ms/step - accuracy: 0.4103 - loss: 1.506 ━━━━━━━━━━━━━━━━━━━━ 37s 441ms/step - accuracy: 0.4034 - loss: 1.509 ━━━━━━━━━━━━━━━━━━━━ 36s 444ms/step - accuracy: 0.3995 - loss: 1.510 ━━━━━━━━━━━━━━━━━━━━ 36s 445ms/step - accuracy: 0.3974 - loss: 1.510 ━━━━━━━━━━━━━━━━━━━━ 35s 444ms/step - accuracy: 0.3958 - loss: 1.510 ━━━━━━━━━━━━━━━━━━━━ 35s 444ms/step - accuracy: 0.3956 - loss: 1.510 ━━━━━━━━━━━━━━━━━━━━ 35s 448ms/step - accuracy: 0.3961 - loss: 1.510 ━━━━━━━━━━━━━━━━━━━━ 34s 446ms/step - accuracy: 0.3968 - loss: 1.510 ━━━━━━━━━━━━━━━━━━━━ 34s 443ms/step - accuracy: 0.3978 - loss: 1.509 ━━━━━━━━━━━━━━━━━━━━ 33s 441ms/step - accuracy: 0.3989 - loss: 1.509 ━━━━━━━━━━━━━━━━━━━━ 32s 439ms/step - accuracy: 0.3997 - loss: 1.509 ━━━━━━━━━━━━━━━━━━━━ 32s 436ms/step - accuracy: 0.4006 - loss: 1.508 ━━━━━━━━━━━━━━━━━━━━ 31s 434ms/step - accuracy: 0.4013 - loss: 1.508 ━━━━━━━━━━━━━━━━━━━━ 31s 432ms/step - accuracy: 0.4019 - loss: 1.507 ━━━━━━━━━━━━━━━━━━━━ 30s 431ms/step - accuracy: 0.4023 - loss: 1.507 ━━━━━━━━━━━━━━━━━━━━ 30s 431ms/step - accuracy: 0.4023 - loss: 1.507 ━━━━━━━━━━━━━━━━━━━━ 29s 430ms/step - accuracy: 0.4024 - loss: 1.506 ━━━━━━━━━━━━━━━━━━━━ 29s 429ms/step - accuracy: 0.4025 - loss: 1.506 ━━━━━━━━━━━━━━━━━━━━ 28s 428ms/step - accuracy: 0.4025 - loss: 1.505 ━━━━━━━━━━━━━━━━━━━━ 28s 428ms/step - accuracy: 0.4025 - loss: 1.505 ━━━━━━━━━━━━━━━━━━━━ 27s 427ms/step - accuracy: 0.4026 - loss: 1.504 ━━━━━━━━━━━━━━━━━━━━ 27s 425ms/step - accuracy: 0.4024 - loss: 1.504 ━━━━━━━━━━━━━━━━━━━━ 26s 424ms/step - accuracy: 0.4023 - loss: 1.504 ━━━━━━━━━━━━━━━━━━━━ 26s 423ms/step - accuracy: 0.4022 - loss: 1.503 ━━━━━━━━━━━━━━━━━━━━ 25s 423ms/step - accuracy: 0.4022 - loss: 1.503 ━━━━━━━━━━━━━━━━━━━━ 25s 423ms/step - accuracy: 0.4021 - loss: 1.502 ━━━━━━━━━━━━━━━━━━━━ 24s 422ms/step - accuracy: 0.4019 - loss: 1.501 ━━━━━━━━━━━━━━━━━━━━ 24s 421ms/step - accuracy: 0.4019 - loss: 1.501 ━━━━━━━━━━━━━━━━━━━━ 24s 421ms/step - accuracy: 0.4019 - loss: 1.500 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.4018 - loss: 1.500 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.4017 - loss: 1.499 ━━━━━━━━━━━━━━━━━━━━ 22s 420ms/step - accuracy: 0.4015 - loss: 1.498 ━━━━━━━━━━━━━━━━━━━━ 22s 421ms/step - accuracy: 0.4013 - loss: 1.498 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - accuracy: 0.4010 - loss: 1.497 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - accuracy: 0.4008 - loss: 1.497 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - accuracy: 0.4007 - loss: 1.496 ━━━━━━━━━━━━━━━━━━━━ 20s 420ms/step - accuracy: 0.4006 - loss: 1.496 ━━━━━━━━━━━━━━━━━━━━ 20s 419ms/step - accuracy: 0.4006 - loss: 1.495 ━━━━━━━━━━━━━━━━━━━━ 19s 418ms/step - accuracy: 0.4006 - loss: 1.494 ━━━━━━━━━━━━━━━━━━━━ 19s 418ms/step - accuracy: 0.4006 - loss: 1.494 ━━━━━━━━━━━━━━━━━━━━ 18s 418ms/step - accuracy: 0.4007 - loss: 1.493 ━━━━━━━━━━━━━━━━━━━━ 18s 417ms/step - accuracy: 0.4006 - loss: 1.492 ━━━━━━━━━━━━━━━━━━━━ 17s 417ms/step - accuracy: 0.4007 - loss: 1.492 ━━━━━━━━━━━━━━━━━━━━ 17s 417ms/step - accuracy: 0.4007 - loss: 1.491 ━━━━━━━━━━━━━━━━━━━━ 17s 417ms/step - accuracy: 0.4007 - loss: 1.491 ━━━━━━━━━━━━━━━━━━━━ 16s 417ms/step - accuracy: 0.4007 - loss: 1.490 ━━━━━━━━━━━━━━━━━━━━ 16s 417ms/step - accuracy: 0.4007 - loss: 1.489 ━━━━━━━━━━━━━━━━━━━━ 15s 417ms/step - accuracy: 0.4007 - loss: 1.489 ━━━━━━━━━━━━━━━━━━━━ 15s 416ms/step - accuracy: 0.4007 - loss: 1.488 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.4006 - loss: 1.488 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.4006 - loss: 1.487 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.4007 - loss ...
# Epoch 3/3
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1:01 673ms/step - accuracy: 0.5312 - loss: 1.14 ━━━━━━━━━━━━━━━━━━━━ 37s 420ms/step - accuracy: 0.5312 - loss: 1.1373 ━━━━━━━━━━━━━━━━━━━━ 37s 417ms/step - accuracy: 0.5382 - loss: 1.133 ━━━━━━━━━━━━━━━━━━━━ 36s 419ms/step - accuracy: 0.5345 - loss: 1.142 ━━━━━━━━━━━━━━━━━━━━ 36s 416ms/step - accuracy: 0.5314 - loss: 1.153 ━━━━━━━━━━━━━━━━━━━━ 35s 417ms/step - accuracy: 0.5261 - loss: 1.163 ━━━━━━━━━━━━━━━━━━━━ 35s 415ms/step - accuracy: 0.5198 - loss: 1.172 ━━━━━━━━━━━━━━━━━━━━ 35s 417ms/step - accuracy: 0.5125 - loss: 1.181 ━━━━━━━━━━━━━━━━━━━━ 34s 417ms/step - accuracy: 0.5076 - loss: 1.188 ━━━━━━━━━━━━━━━━━━━━ 34s 417ms/step - accuracy: 0.5022 - loss: 1.196 ━━━━━━━━━━━━━━━━━━━━ 33s 415ms/step - accuracy: 0.4994 - loss: 1.202 ━━━━━━━━━━━━━━━━━━━━ 33s 414ms/step - accuracy: 0.4955 - loss: 1.207 ━━━━━━━━━━━━━━━━━━━━ 32s 413ms/step - accuracy: 0.4914 - loss: 1.212 ━━━━━━━━━━━━━━━━━━━━ 32s 413ms/step - accuracy: 0.4870 - loss: 1.217 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.4837 - loss: 1.221 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.4809 - loss: 1.224 ━━━━━━━━━━━━━━━━━━━━ 30s 413ms/step - accuracy: 0.4782 - loss: 1.227 ━━━━━━━━━━━━━━━━━━━━ 30s 413ms/step - accuracy: 0.4759 - loss: 1.230 ━━━━━━━━━━━━━━━━━━━━ 30s 415ms/step - accuracy: 0.4737 - loss: 1.233 ━━━━━━━━━━━━━━━━━━━━ 29s 415ms/step - accuracy: 0.4717 - loss: 1.235 ━━━━━━━━━━━━━━━━━━━━ 29s 415ms/step - accuracy: 0.4697 - loss: 1.238 ━━━━━━━━━━━━━━━━━━━━ 28s 414ms/step - accuracy: 0.4680 - loss: 1.240 ━━━━━━━━━━━━━━━━━━━━ 28s 414ms/step - accuracy: 0.4664 - loss: 1.242 ━━━━━━━━━━━━━━━━━━━━ 28s 413ms/step - accuracy: 0.4649 - loss: 1.244 ━━━━━━━━━━━━━━━━━━━━ 27s 412ms/step - accuracy: 0.4634 - loss: 1.245 ━━━━━━━━━━━━━━━━━━━━ 27s 412ms/step - accuracy: 0.4620 - loss: 1.247 ━━━━━━━━━━━━━━━━━━━━ 26s 412ms/step - accuracy: 0.4606 - loss: 1.248 ━━━━━━━━━━━━━━━━━━━━ 26s 412ms/step - accuracy: 0.4593 - loss: 1.250 ━━━━━━━━━━━━━━━━━━━━ 25s 412ms/step - accuracy: 0.4581 - loss: 1.251 ━━━━━━━━━━━━━━━━━━━━ 25s 411ms/step - accuracy: 0.4569 - loss: 1.252 ━━━━━━━━━━━━━━━━━━━━ 25s 411ms/step - accuracy: 0.4559 - loss: 1.253 ━━━━━━━━━━━━━━━━━━━━ 24s 410ms/step - accuracy: 0.4549 - loss: 1.255 ━━━━━━━━━━━━━━━━━━━━ 24s 411ms/step - accuracy: 0.4541 - loss: 1.256 ━━━━━━━━━━━━━━━━━━━━ 23s 411ms/step - accuracy: 0.4535 - loss: 1.257 ━━━━━━━━━━━━━━━━━━━━ 23s 411ms/step - accuracy: 0.4530 - loss: 1.258 ━━━━━━━━━━━━━━━━━━━━ 23s 411ms/step - accuracy: 0.4525 - loss: 1.259 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.4520 - loss: 1.259 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.4514 - loss: 1.260 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - accuracy: 0.4509 - loss: 1.261 ━━━━━━━━━━━━━━━━━━━━ 21s 414ms/step - accuracy: 0.4503 - loss: 1.262 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - accuracy: 0.4498 - loss: 1.262 ━━━━━━━━━━━━━━━━━━━━ 20s 415ms/step - accuracy: 0.4494 - loss: 1.263 ━━━━━━━━━━━━━━━━━━━━ 20s 414ms/step - accuracy: 0.4489 - loss: 1.264 ━━━━━━━━━━━━━━━━━━━━ 19s 415ms/step - accuracy: 0.4485 - loss: 1.265 ━━━━━━━━━━━━━━━━━━━━ 19s 415ms/step - accuracy: 0.4481 - loss: 1.265 ━━━━━━━━━━━━━━━━━━━━ 19s 415ms/step - accuracy: 0.4476 - loss: 1.266 ━━━━━━━━━━━━━━━━━━━━ 18s 415ms/step - accuracy: 0.4472 - loss: 1.266 ━━━━━━━━━━━━━━━━━━━━ 18s 415ms/step - accuracy: 0.4468 - loss: 1.267 ━━━━━━━━━━━━━━━━━━━━ 17s 416ms/step - accuracy: 0.4464 - loss: 1.267 ━━━━━━━━━━━━━━━━━━━━ 17s 416ms/step - accuracy: 0.4459 - loss: 1.268 ━━━━━━━━━━━━━━━━━━━━ 17s 416ms/step - accuracy: 0.4455 - loss: 1.268 ━━━━━━━━━━━━━━━━━━━━ 16s 415ms/step - accuracy: 0.4451 - loss: 1.269 ━━━━━━━━━━━━━━━━━━━━ 16s 415ms/step - accuracy: 0.4447 - loss: 1.269 ━━━━━━━━━━━━━━━━━━━━ 15s 415ms/step - accuracy: 0.4443 - loss: 1.270 ━━━━━━━━━━━━━━━━━━━━ 15s 415ms/step - accuracy: 0.4440 - loss: 1.270 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.4437 - loss: 1.270 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.4433 - loss: 1.271 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.4430 - los ...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 743ms/step - accuracy: 0.4688 - loss: 1.07 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.4609 - loss: 1.10 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.4878 - loss: 1.10 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4909 - loss: 1.12 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.4877 - loss: 1.14 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.4802 - loss: 1.15 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4754 - loss: 1.16 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4716 - loss: 1.17 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4690 - loss: 1.17 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4674 - loss: 1.18 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.4652 - loss: 1.18 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4637 - loss: 1.18 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.4624 - loss: 1.1901
# CNN Test Evaluation: [1.2204724550247192, 0.4468664824962616]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▇█</td></tr><tr><td>epoch/epoch</td><td>▁▅█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▄▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▄█</td></tr><tr><td>epoch/val_loss</td><td>█▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.42984</td></tr><tr><td>epoch/epoch</td><td>2</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>1.27997</td></tr><tr><td>epoch/val_accuracy</td><td>0.40054</td></tr><tr><td>epoch/val_loss</td><td>1.25996</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CNN_flowers_run</strong> at: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/cpmagrre' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/cpmagrre</a><br> View project at: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers</a><br>Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250125_035807-cpmagrre\logs</code>

# %% [markdown]
# # Custom Wrapper Layer: 채널 순서 강제 & 출력 스펙 지정

# %%
import tensorflow as tf
from transformers import TFViTModel

class TFPixelValuesWrapper(tf.keras.layers.Layer):
    def __init__(
        self,
        model_name="google/vit-base-patch16-224-in21k",
        base_trainable=False,
        **kwargs
    ):
        super().__init__()
        # 사전 학습된 TFViTModel 로드
        self.base_vit = TFViTModel.from_pretrained(model_name)
        self.base_vit.trainable = base_trainable
        
        # ViT Base 모델의 히든 크기 (예: vit-base는 768)
        self.hidden_size = self.base_vit.config.hidden_size
        # 이미지 패치의 크기 (기본 16), 최종 시퀀스 길이 = (H/patch_size)*(W/patch_size)
        self.patch_size = self.base_vit.config.patch_size
        self.image_size = self.base_vit.config.image_size
        # 예: 224×224 이미지를 patch_size=16으로 나누면 seq_len=196

    def call(self, inputs, training=False):
        """
        inputs: (None, 224, 224, 3) 형태의 KerasTensor (channels-last)
        내부에서 (batch, 224, 224, 3)를 (batch, 3, 224, 224)로 변환 후 ViT에 전달
        """
        # Keras의 channels-last 텐서를 channels-first로 강제 변환
        # TFViTModel이 내부에서 또 transpose를 시도하는 이슈를 피하기 위해
        pixel_values = tf.transpose(inputs, perm=[0, 3, 1, 2])  # (None, 3, 224, 224)

        # ViT 호출
        outputs = self.base_vit(pixel_values=pixel_values, training=training)
        # last_hidden_state: (batch, seq_len, hidden_size)
        return outputs.last_hidden_state

    def compute_output_shape(self, input_shape):
        """
        input_shape = (None, 224, 224, 3)
        ViT-base: seq_len = (224/16)*(224/16) = 196, hidden_size = 768
        따라서 출력 형태는 (batch, 196, 768)
        """
        batch_size = input_shape[0]
        seq_len = (self.image_size // self.patch_size) * (self.image_size // self.patch_size)
        return (batch_size, seq_len, self.hidden_size)

    def compute_output_signature(self, input_signature):
        """
        Keras Functional API가 타입 힌트를 정확히 알 수 있도록 별도 구현.
        """
        import tensorflow as tf
        out_shape = self.compute_output_shape(input_signature.shape)
        return tf.TensorSpec(shape=out_shape, dtype=tf.float32)

# %% [markdown]
# # 6) Functional API 기반 ViT 모델 빌드 함수 / Build ViT Model with Functional API
# **[KOR]** 사전 학습된 ViT를 불러와, Dense와 Dropout, BatchNorm 등을 파라미터로 동적으로 추가/조절하는 함수를 만듭니다.
# **[ENG]** Load a pretrained ViT, then add Dense, Dropout, and BatchNorm layers dynamically based on hyperparameters in a build function.

# %%
def build_vit_model(
    num_classes,
    num_dense_layers=1,
    dense_units=128,
    dropout_rate=0.3,
    use_batchnorm=True,
    base_trainable=False
):
    inputs = tf.keras.Input(shape=(224, 224, 3), name="input_images")

    # 위 래퍼 레이어 인스턴스
    vit_layer = TFPixelValuesWrapper(
        model_name="google/vit-base-patch16-224-in21k",
        base_trainable=base_trainable,
    )

    # ViT 출력: [batch, seq_len, hidden_dim]
    vit_outputs = vit_layer(inputs)

    # seq_len 차원 풀링
    x = tf.keras.layers.GlobalAveragePooling1D()(vit_outputs)

    # 추가 Dense 블록
    for _ in range(num_dense_layers):
        x = tf.keras.layers.Dense(dense_units, activation='relu')(x)
        if use_batchnorm:
            x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(dropout_rate)(x)

    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs)
    return model

# %% [markdown]
# # 7) ViT 모델 학습 (단일 실험 예시) / Train the ViT Model (Single Experiment Example)
# **[KOR]** 위에서 정의한 `build_vit_model`을 사용해 ViT 모델을 하나 구성해 보고, W&B에 로깅합니다.
# **[ENG]** Use `build_vit_model` to create a ViT model, then train and log metrics to W&B as a single-run example.

# %%
! pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cpu

# %%
# W&B 초기화
wandb.init(project="ViT_vs_CNN_flowers")

num_classes = 5  # 예: tf_flowers 데이터셋은 5개 클래스

# 모델 빌드
vit_model = build_vit_model(
    num_classes=num_classes,
    num_dense_layers=2,
    dense_units=128,
    dropout_rate=0.3,
    use_batchnorm=True,
    base_trainable=False
)

vit_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

vit_model.fit(
    train_batches,
    validation_data=val_batches,
    epochs=3,
    callbacks=[
        WandbMetricsLogger(log_freq="epoch"),
        WandbModelCheckpoint("model_checkpoint.keras")
    ]
)

test_loss, test_acc = vit_model.evaluate(test_batches)
wandb.log({"test_loss": test_loss, "test_accuracy": test_acc})
print("ViT Test Accuracy:", test_acc)
wandb.finish()
# Out:
# All PyTorch model weights were used when initializing TFViTModel.
#
# All the weights of TFViTModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
# Epoch 1/3
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19:26 13s/step - accuracy: 0.2500 - loss: 2.848 ━━━━━━━━━━━━━━━━━━━━ 5:52 4s/step - accuracy: 0.2578 - loss: 2.7002  ━━━━━━━━━━━━━━━━━━━━ 5:45 4s/step - accuracy: 0.2483 - loss: 2.626 ━━━━━━━━━━━━━━━━━━━━ 5:44 4s/step - accuracy: 0.2389 - loss: 2.621 ━━━━━━━━━━━━━━━━━━━━ 5:38 4s/step - accuracy: 0.2349 - loss: 2.610 ━━━━━━━━━━━━━━━━━━━━ 5:34 4s/step - accuracy: 0.2331 - loss: 2.598 ━━━━━━━━━━━━━━━━━━━━ 5:37 4s/step - accuracy: 0.2310 - loss: 2.593 ━━━━━━━━━━━━━━━━━━━━ 5:35 4s/step - accuracy: 0.2295 - loss: 2.587 ━━━━━━━━━━━━━━━━━━━━ 5:29 4s/step - accuracy: 0.2283 - loss: 2.580 ━━━━━━━━━━━━━━━━━━━━ 5:24 4s/step - accuracy: 0.2286 - loss: 2.566 ━━━━━━━━━━━━━━━━━━━━ 5:19 4s/step - accuracy: 0.2285 - loss: 2.552 ━━━━━━━━━━━━━━━━━━━━ 5:15 4s/step - accuracy: 0.2290 - loss: 2.538 ━━━━━━━━━━━━━━━━━━━━ 5:09 4s/step - accuracy: 0.2298 - loss: 2.524 ━━━━━━━━━━━━━━━━━━━━ 5:05 4s/step - accuracy: 0.2314 - loss: 2.508 ━━━━━━━━━━━━━━━━━━━━ 5:01 4s/step - accuracy: 0.2331 - loss: 2.491 ━━━━━━━━━━━━━━━━━━━━ 4:55 4s/step - accuracy: 0.2355 - loss: 2.474 ━━━━━━━━━━━━━━━━━━━━ 4:51 4s/step - accuracy: 0.2383 - loss: 2.456 ━━━━━━━━━━━━━━━━━━━━ 4:47 4s/step - accuracy: 0.2412 - loss: 2.439 ━━━━━━━━━━━━━━━━━━━━ 4:43 4s/step - accuracy: 0.2442 - loss: 2.423 ━━━━━━━━━━━━━━━━━━━━ 4:38 4s/step - accuracy: 0.2475 - loss: 2.406 ━━━━━━━━━━━━━━━━━━━━ 4:33 4s/step - accuracy: 0.2507 - loss: 2.390 ━━━━━━━━━━━━━━━━━━━━ 4:29 4s/step - accuracy: 0.2540 - loss: 2.374 ━━━━━━━━━━━━━━━━━━━━ 4:26 4s/step - accuracy: 0.2575 - loss: 2.357 ━━━━━━━━━━━━━━━━━━━━ 4:22 4s/step - accuracy: 0.2613 - loss: 2.341 ━━━━━━━━━━━━━━━━━━━━ 4:19 4s/step - accuracy: 0.2651 - loss: 2.324 ━━━━━━━━━━━━━━━━━━━━ 4:15 4s/step - accuracy: 0.2690 - loss: 2.308 ━━━━━━━━━━━━━━━━━━━━ 4:11 4s/step - accuracy: 0.2729 - loss: 2.293 ━━━━━━━━━━━━━━━━━━━━ 4:07 4s/step - accuracy: 0.2767 - loss: 2.277 ━━━━━━━━━━━━━━━━━━━━ 4:04 4s/step - accuracy: 0.2803 - loss: 2.263 ━━━━━━━━━━━━━━━━━━━━ 4:00 4s/step - accuracy: 0.2840 - loss: 2.248 ━━━━━━━━━━━━━━━━━━━━ 3:57 4s/step - accuracy: 0.2876 - loss: 2.233 ━━━━━━━━━━━━━━━━━━━━ 3:52 4s/step - accuracy: 0.2912 - loss: 2.218 ━━━━━━━━━━━━━━━━━━━━ 3:48 4s/step - accuracy: 0.2948 - loss: 2.204 ━━━━━━━━━━━━━━━━━━━━ 3:44 4s/step - accuracy: 0.2984 - loss: 2.190 ━━━━━━━━━━━━━━━━━━━━ 3:40 4s/step - accuracy: 0.3020 - loss: 2.176 ━━━━━━━━━━━━━━━━━━━━ 3:36 4s/step - accuracy: 0.3055 - loss: 2.162 ━━━━━━━━━━━━━━━━━━━━ 3:33 4s/step - accuracy: 0.3090 - loss: 2.149 ━━━━━━━━━━━━━━━━━━━━ 3:29 4s/step - accuracy: 0.3125 - loss: 2.135 ━━━━━━━━━━━━━━━━━━━━ 3:25 4s/step - accuracy: 0.3160 - loss: 2.122 ━━━━━━━━━━━━━━━━━━━━ 3:22 4s/step - accuracy: 0.3195 - loss: 2.109 ━━━━━━━━━━━━━━━━━━━━ 3:18 4s/step - accuracy: 0.3229 - loss: 2.097 ━━━━━━━━━━━━━━━━━━━━ 3:14 4s/step - accuracy: 0.3263 - loss: 2.084 ━━━━━━━━━━━━━━━━━━━━ 3:10 4s/step - accuracy: 0.3296 - loss: 2.072 ━━━━━━━━━━━━━━━━━━━━ 3:06 4s/step - accuracy: 0.3330 - loss: 2.061 ━━━━━━━━━━━━━━━━━━━━ 3:03 4s/step - accuracy: 0.3363 - loss: 2.049 ━━━━━━━━━━━━━━━━━━━━ 2:59 4s/step - accuracy: 0.3397 - loss: 2.037 ━━━━━━━━━━━━━━━━━━━━ 2:55 4s/step - accuracy: 0.3430 - loss: 2.026 ━━━━━━━━━━━━━━━━━━━━ 2:50 4s/step - accuracy: 0.3463 - loss: 2.015 ━━━━━━━━━━━━━━━━━━━━ 2:46 4s/step - accuracy: 0.3495 - loss: 2.004 ━━━━━━━━━━━━━━━━━━━━ 2:42 4s/step - accuracy: 0.3527 - loss: 1.993 ━━━━━━━━━━━━━━━━━━━━ 2:39 4s/step - accuracy: 0.3558 - loss: 1.982 ━━━━━━━━━━━━━━━━━━━━ 2:35 4s/step - accuracy: 0.3588 - loss: 1.972 ━━━━━━━━━━━━━━━━━━━━ 2:31 4s/step - accuracy: 0.3618 - loss: 1.962 ━━━━━━━━━━━━━━━━━━━━ 2:27 4s/step - accuracy: 0.3647 - loss: 1.952 ━━━━━━━━━━━━━━━━━━━━ 2:24 4s/step - accuracy: 0.3676 - loss: 1.942 ━━━━━━━━━━━━━━━━━━━━ 2:20 4s/step - accuracy: 0.3705 - loss: 1.932 ━━━━━━━━━━━━━━━━━━━━ 2:16 4s/step - accuracy: 0.3733 - loss: 1.922 ━━━━━━━━━━━━━━━━━━━━ 2:12 4s/step - accuracy: 0.3762 - loss: 1.913 ━━━━━━━━━━━━━━━━━━━━ 2:08 4s/step - accuracy: 0.3790 - loss: 1.903 ━━━━━━━━━━━━━━━━━━━━ 2:04 4s/step - a ...
# Epoch 2/3
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7:09 5s/step - accuracy: 0.8438 - loss: 0.539 ━━━━━━━━━━━━━━━━━━━━ 6:12 4s/step - accuracy: 0.8594 - loss: 0.479 ━━━━━━━━━━━━━━━━━━━━ 6:02 4s/step - accuracy: 0.8611 - loss: 0.469 ━━━━━━━━━━━━━━━━━━━━ 6:07 4s/step - accuracy: 0.8626 - loss: 0.459 ━━━━━━━━━━━━━━━━━━━━ 6:02 4s/step - accuracy: 0.8551 - loss: 0.465 ━━━━━━━━━━━━━━━━━━━━ 6:00 4s/step - accuracy: 0.8541 - loss: 0.460 ━━━━━━━━━━━━━━━━━━━━ 5:58 4s/step - accuracy: 0.8532 - loss: 0.458 ━━━━━━━━━━━━━━━━━━━━ 5:57 4s/step - accuracy: 0.8525 - loss: 0.459 ━━━━━━━━━━━━━━━━━━━━ 5:56 4s/step - accuracy: 0.8523 - loss: 0.459 ━━━━━━━━━━━━━━━━━━━━ 5:51 4s/step - accuracy: 0.8524 - loss: 0.458 ━━━━━━━━━━━━━━━━━━━━ 5:45 4s/step - accuracy: 0.8524 - loss: 0.459 ━━━━━━━━━━━━━━━━━━━━ 5:45 4s/step - accuracy: 0.8523 - loss: 0.458 ━━━━━━━━━━━━━━━━━━━━ 5:44 4s/step - accuracy: 0.8528 - loss: 0.457 ━━━━━━━━━━━━━━━━━━━━ 5:44 4s/step - accuracy: 0.8536 - loss: 0.454 ━━━━━━━━━━━━━━━━━━━━ 5:43 4s/step - accuracy: 0.8544 - loss: 0.452 ━━━━━━━━━━━━━━━━━━━━ 5:41 4s/step - accuracy: 0.8550 - loss: 0.450 ━━━━━━━━━━━━━━━━━━━━ 5:37 4s/step - accuracy: 0.8556 - loss: 0.449 ━━━━━━━━━━━━━━━━━━━━ 5:32 4s/step - accuracy: 0.8564 - loss: 0.447 ━━━━━━━━━━━━━━━━━━━━ 5:28 5s/step - accuracy: 0.8572 - loss: 0.446 ━━━━━━━━━━━━━━━━━━━━ 5:25 5s/step - accuracy: 0.8580 - loss: 0.444 ━━━━━━━━━━━━━━━━━━━━ 5:20 5s/step - accuracy: 0.8586 - loss: 0.444 ━━━━━━━━━━━━━━━━━━━━ 5:14 4s/step - accuracy: 0.8590 - loss: 0.443 ━━━━━━━━━━━━━━━━━━━━ 5:09 4s/step - accuracy: 0.8594 - loss: 0.442 ━━━━━━━━━━━━━━━━━━━━ 5:03 4s/step - accuracy: 0.8599 - loss: 0.442 ━━━━━━━━━━━━━━━━━━━━ 4:57 4s/step - accuracy: 0.8602 - loss: 0.442 ━━━━━━━━━━━━━━━━━━━━ 4:52 4s/step - accuracy: 0.8604 - loss: 0.441 ━━━━━━━━━━━━━━━━━━━━ 4:47 4s/step - accuracy: 0.8607 - loss: 0.441 ━━━━━━━━━━━━━━━━━━━━ 4:41 4s/step - accuracy: 0.8609 - loss: 0.441 ━━━━━━━━━━━━━━━━━━━━ 4:36 4s/step - accuracy: 0.8611 - loss: 0.440 ━━━━━━━━━━━━━━━━━━━━ 4:32 4s/step - accuracy: 0.8613 - loss: 0.440 ━━━━━━━━━━━━━━━━━━━━ 4:27 4s/step - accuracy: 0.8615 - loss: 0.439 ━━━━━━━━━━━━━━━━━━━━ 4:22 4s/step - accuracy: 0.8617 - loss: 0.439 ━━━━━━━━━━━━━━━━━━━━ 4:18 4s/step - accuracy: 0.8618 - loss: 0.439 ━━━━━━━━━━━━━━━━━━━━ 4:13 4s/step - accuracy: 0.8619 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 4:08 4s/step - accuracy: 0.8621 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 4:03 4s/step - accuracy: 0.8621 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 3:58 4s/step - accuracy: 0.8623 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 3:54 4s/step - accuracy: 0.8623 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 3:49 4s/step - accuracy: 0.8624 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 3:45 4s/step - accuracy: 0.8624 - loss: 0.438 ━━━━━━━━━━━━━━━━━━━━ 3:41 4s/step - accuracy: 0.8624 - loss: 0.437 ━━━━━━━━━━━━━━━━━━━━ 3:36 4s/step - accuracy: 0.8624 - loss: 0.437 ━━━━━━━━━━━━━━━━━━━━ 3:32 4s/step - accuracy: 0.8624 - loss: 0.437 ━━━━━━━━━━━━━━━━━━━━ 3:27 4s/step - accuracy: 0.8624 - loss: 0.437 ━━━━━━━━━━━━━━━━━━━━ 3:22 4s/step - accuracy: 0.8624 - loss: 0.437 ━━━━━━━━━━━━━━━━━━━━ 3:18 4s/step - accuracy: 0.8624 - loss: 0.436 ━━━━━━━━━━━━━━━━━━━━ 3:13 4s/step - accuracy: 0.8624 - loss: 0.436 ━━━━━━━━━━━━━━━━━━━━ 3:09 4s/step - accuracy: 0.8624 - loss: 0.436 ━━━━━━━━━━━━━━━━━━━━ 3:04 4s/step - accuracy: 0.8624 - loss: 0.435 ━━━━━━━━━━━━━━━━━━━━ 3:00 4s/step - accuracy: 0.8625 - loss: 0.435 ━━━━━━━━━━━━━━━━━━━━ 2:55 4s/step - accuracy: 0.8625 - loss: 0.435 ━━━━━━━━━━━━━━━━━━━━ 2:51 4s/step - accuracy: 0.8626 - loss: 0.434 ━━━━━━━━━━━━━━━━━━━━ 2:47 4s/step - accuracy: 0.8626 - loss: 0.434 ━━━━━━━━━━━━━━━━━━━━ 2:43 4s/step - accuracy: 0.8626 - loss: 0.433 ━━━━━━━━━━━━━━━━━━━━ 2:39 4s/step - accuracy: 0.8627 - loss: 0.433 ━━━━━━━━━━━━━━━━━━━━ 2:34 4s/step - accuracy: 0.8627 - loss: 0.433 ━━━━━━━━━━━━━━━━━━━━ 2:30 4s/step - accuracy: 0.8627 - loss: 0.432 ━━━━━━━━━━━━━━━━━━━━ 2:26 4s/step - accuracy: 0.8627 - loss: 0.432 ━━━━━━━━━━━━━━━━━━━━ 2:22 4s/step - accuracy: 0.8626 - loss: 0.432 ━━━━━━━━━━━━━━━━━━━━ 2:17 4s/step - accur ...
# Epoch 3/3
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6:59 5s/step - accuracy: 0.9375 - loss: 0.206 ━━━━━━━━━━━━━━━━━━━━ 6:23 4s/step - accuracy: 0.9297 - loss: 0.253 ━━━━━━━━━━━━━━━━━━━━ 6:16 4s/step - accuracy: 0.9184 - loss: 0.274 ━━━━━━━━━━━━━━━━━━━━ 6:16 4s/step - accuracy: 0.9173 - loss: 0.275 ━━━━━━━━━━━━━━━━━━━━ 6:27 4s/step - accuracy: 0.9151 - loss: 0.281 ━━━━━━━━━━━━━━━━━━━━ 6:21 4s/step - accuracy: 0.9162 - loss: 0.281 ━━━━━━━━━━━━━━━━━━━━ 6:15 4s/step - accuracy: 0.9167 - loss: 0.284 ━━━━━━━━━━━━━━━━━━━━ 6:09 4s/step - accuracy: 0.9154 - loss: 0.288 ━━━━━━━━━━━━━━━━━━━━ 6:07 4s/step - accuracy: 0.9136 - loss: 0.292 ━━━━━━━━━━━━━━━━━━━━ 6:07 4s/step - accuracy: 0.9123 - loss: 0.296 ━━━━━━━━━━━━━━━━━━━━ 6:03 4s/step - accuracy: 0.9107 - loss: 0.300 ━━━━━━━━━━━━━━━━━━━━ 5:59 4s/step - accuracy: 0.9086 - loss: 0.304 ━━━━━━━━━━━━━━━━━━━━ 5:56 5s/step - accuracy: 0.9067 - loss: 0.308 ━━━━━━━━━━━━━━━━━━━━ 5:52 5s/step - accuracy: 0.9053 - loss: 0.310 ━━━━━━━━━━━━━━━━━━━━ 5:47 5s/step - accuracy: 0.9044 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 5:41 4s/step - accuracy: 0.9037 - loss: 0.312 ━━━━━━━━━━━━━━━━━━━━ 5:35 4s/step - accuracy: 0.9033 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 5:29 4s/step - accuracy: 0.9031 - loss: 0.313 ━━━━━━━━━━━━━━━━━━━━ 5:23 4s/step - accuracy: 0.9028 - loss: 0.314 ━━━━━━━━━━━━━━━━━━━━ 5:17 4s/step - accuracy: 0.9024 - loss: 0.315 ━━━━━━━━━━━━━━━━━━━━ 5:12 4s/step - accuracy: 0.9022 - loss: 0.315 ━━━━━━━━━━━━━━━━━━━━ 5:06 4s/step - accuracy: 0.9022 - loss: 0.315 ━━━━━━━━━━━━━━━━━━━━ 5:00 4s/step - accuracy: 0.9021 - loss: 0.316 ━━━━━━━━━━━━━━━━━━━━ 4:55 4s/step - accuracy: 0.9019 - loss: 0.317 ━━━━━━━━━━━━━━━━━━━━ 4:49 4s/step - accuracy: 0.9016 - loss: 0.318 ━━━━━━━━━━━━━━━━━━━━ 4:45 4s/step - accuracy: 0.9014 - loss: 0.319 ━━━━━━━━━━━━━━━━━━━━ 4:40 4s/step - accuracy: 0.9012 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 4:36 4s/step - accuracy: 0.9011 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 4:32 4s/step - accuracy: 0.9009 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 4:27 4s/step - accuracy: 0.9007 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 4:22 4s/step - accuracy: 0.9006 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 4:17 4s/step - accuracy: 0.9005 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 4:12 4s/step - accuracy: 0.9004 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 4:08 4s/step - accuracy: 0.9003 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 4:03 4s/step - accuracy: 0.9003 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 3:58 4s/step - accuracy: 0.9003 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 3:54 4s/step - accuracy: 0.9002 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 3:50 4s/step - accuracy: 0.9002 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 3:45 4s/step - accuracy: 0.9003 - loss: 0.322 ━━━━━━━━━━━━━━━━━━━━ 3:40 4s/step - accuracy: 0.9004 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:36 4s/step - accuracy: 0.9004 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:32 4s/step - accuracy: 0.9005 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:27 4s/step - accuracy: 0.9005 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:23 4s/step - accuracy: 0.9006 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:18 4s/step - accuracy: 0.9007 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:14 4s/step - accuracy: 0.9007 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:10 4s/step - accuracy: 0.9008 - loss: 0.321 ━━━━━━━━━━━━━━━━━━━━ 3:06 4s/step - accuracy: 0.9009 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 3:01 4s/step - accuracy: 0.9009 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:57 4s/step - accuracy: 0.9009 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:53 4s/step - accuracy: 0.9009 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:48 4s/step - accuracy: 0.9009 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:44 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:40 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:36 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:32 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:27 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:23 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:19 4s/step - accuracy: 0.9010 - loss: 0.320 ━━━━━━━━━━━━━━━━━━━━ 2:14 4s/step - accur ...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 46s 4s/step - accuracy: 0.9062 - loss: 0.37 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 0.9062 - loss: 0.36 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step - accuracy: 0.9132 - loss: 0.34 ━━━━━━━━━━━━━━━━━━━━ 33s 4s/step - accuracy: 0.9115 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step - accuracy: 0.9129 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - accuracy: 0.9153 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step - accuracy: 0.9185 - loss: 0.35 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.9218 - loss: 0.34 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.9232 - loss: 0.34 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - accuracy: 0.9243 - loss: 0.3484 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.9247 - loss: 0.349 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9251 - loss: 0.349 ━━━━━━━━━━━━━━━━━━━━ 47s 4s/step - accuracy: 0.9254 - loss: 0.3502
# ViT Test Accuracy: 0.9291552901268005
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▇█</td></tr><tr><td>epoch/epoch</td><td>▁▅█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▅█</td></tr><tr><td>epoch/val_loss</td><td>█▄▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.90463</td></tr><tr><td>epoch/epoch</td><td>2</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>0.29781</td></tr><tr><td>epoch/val_accuracy</td><td>0.94005</td></tr><tr><td>epoch/val_loss</td><td>0.35392</td></tr><tr><td>test_accuracy</td><td>0.92916</td></tr><tr><td>test_loss</td><td>0.35586</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">whole-forest-8</strong> at: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/qcp9fy37' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/qcp9fy37</a><br> View project at: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers</a><br>Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250125_105828-qcp9fy37\logs</code>

# %% [markdown]
# # 8) W&B Sweep 설정 예시 (sweep.yaml) / W&B Sweep Configuration Example
# **[KOR]** 다양한 하이퍼파라미터(레이어 수, Dropout 비율, BatchNorm 여부 등)를 탐색하기 위한 예시 스윕 설정입니다.
# **[ENG]** An example sweep configuration for exploring various hyperparameters (number of Dense layers, dropout rate, batch normalization, etc.).

# %%
sweep_config = '''
method: bayes
metric:
  name: val_accuracy
  goal: maximize
parameters:
  num_dense_layers:
    values: [1, 2, 3]
  dense_units:
    values: [64, 128, 256]
  dropout_rate:
    values: [0.2, 0.3, 0.5]
  use_batchnorm:
    values: [true, false]
  base_trainable:
    values: [false, true]
  learning_rate:
    values: [1e-4, 1e-5]
  batch_size:
    values: [16, 32]
  epochs:
    values: [5, 10]
'''

with open('sweep.yaml', 'w') as file:
    file.write(sweep_config)

print("sweep.yaml 파일이 생성되었습니다.")
# Out:
# sweep.yaml 파일이 생성되었습니다.

# %% [markdown]
# # 9) Sweep 트레이닝 함수 / Sweep Training Function
# **[KOR]** Sweep 에이전트가 각 실험마다 호출할 함수입니다. 여러 조합을 자동 시도하며 결과를 W&B에 기록합니다.
# **[ENG]** This function is called by the sweep agent for each experiment, automatically trying different combinations and logging results to W&B.

# %%
def train_sweep(config=None):
    with wandb.init(config=config):
        config = wandb.config

        # 데이터셋의 배치를 다시 설정하려면 아래와 같이 batch_size 재지정 가능
        # If you want to re-batch data based on config.batch_size, do:
        current_train_batches = train_ds.batch(config.batch_size).prefetch(tf.data.AUTOTUNE)
        current_val_batches = val_ds.batch(config.batch_size).prefetch(tf.data.AUTOTUNE)
        current_test_batches = test_ds.batch(config.batch_size).prefetch(tf.data.AUTOTUNE)

        # 모델 빌드
        model = build_vit_model(
            num_classes=num_classes,
            num_dense_layers=config.num_dense_layers,
            dense_units=config.dense_units,
            dropout_rate=config.dropout_rate,
            use_batchnorm=config.use_batchnorm,
            base_trainable=config.base_trainable
        )

        optimizer = tf.keras.optimizers.Adam(learning_rate=config.learning_rate)
        model.compile(
            optimizer=optimizer,
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        model.fit(
            current_train_batches,
            validation_data=current_val_batches,
            epochs=config.epochs,
            callbacks=[WandbMetricsLogger(log_freq="epoch"),WandbModelCheckpoint("model_checkpoint.keras")]
        )

        test_loss, test_acc = model.evaluate(current_test_batches)
        wandb.log({"test_loss": test_loss, "test_accuracy": test_acc})
        print("Test Accuracy:", test_acc)

# %% [markdown]
# # 10) Sweep 실행 / Launch the Sweep
# **[KOR]** 아래 코드(또는 CLI 명령어)를 통해 sweep을 생성하고, 에이전트를 실행하면 다양한 아키텍처 및 HP 조합이 자동으로 탐색됩니다.
# **[ENG]** Use the code (or CLI commands) below to create a sweep and run an agent, automatically exploring multiple architecture and hyperparameter combinations.

# %%
# (주의) 실제로 실행할 때 주석 해제
import yaml
sweep_config_dict = yaml.safe_load(sweep_config)
sweep_id = wandb.sweep(sweep_config_dict, project="ViT_vs_CNN_flowers")
wandb.agent(sweep_id, function=train_sweep)
# Out:
# Create sweep with ID: xff9u3my
# Sweep URL: https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/sweeps/xff9u3my
# wandb: Agent Starting Run: opqy993s with config:
# wandb: 	base_trainable: False
# wandb: 	batch_size: 32
# wandb: 	dense_units: 64
# wandb: 	dropout_rate: 0.2
# wandb: 	epochs: 5
# wandb: 	learning_rate: 1e-05
# wandb: 	num_dense_layers: 1
# wandb: 	use_batchnorm: False
# Tracking run with wandb version 0.19.4
# Run data is saved locally in <code>c:\Users\User\Documents\GitHub\mlops\wandb\run-20250125_142728-opqy993s</code>
# Syncing run <strong><a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/opqy993s' target="_blank">wandering-sweep-1</a></strong> to <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/sweeps/xff9u3my' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/sweeps/xff9u3my</a>
#  View project at <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers</a>
#  View sweep at <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/sweeps/xff9u3my' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/sweeps/xff9u3my</a>
#  View run at <a href='https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/opqy993s' target="_blank">https://wandb.ai/realx1212-aijosh/ViT_vs_CNN_flowers/runs/opqy993s</a>
# All PyTorch model weights were used when initializing TFViTModel.
#
# All the weights of TFViTModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
# Epoch 1/5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19:12 13s/step - accuracy: 0.1875 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 5:50 4s/step - accuracy: 0.1875 - loss: 1.6271  ━━━━━━━━━━━━━━━━━━━━ 5:37 4s/step - accuracy: 0.1910 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 5:39 4s/step - accuracy: 0.1979 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 5:36 4s/step - accuracy: 0.2033 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 5:38 4s/step - accuracy: 0.2016 - loss: 1.629 ━━━━━━━━━━━━━━━━━━━━ 5:38 4s/step - accuracy: 0.1996 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 5:31 4s/step - accuracy: 0.1966 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 5:25 4s/step - accuracy: 0.1956 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 5:20 4s/step - accuracy: 0.1951 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 5:15 4s/step - accuracy: 0.1946 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 5:12 4s/step - accuracy: 0.1945 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 5:08 4s/step - accuracy: 0.1949 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 5:04 4s/step - accuracy: 0.1950 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:59 4s/step - accuracy: 0.1948 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:56 4s/step - accuracy: 0.1947 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:51 4s/step - accuracy: 0.1947 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:48 4s/step - accuracy: 0.1946 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:44 4s/step - accuracy: 0.1941 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:39 4s/step - accuracy: 0.1938 - loss: 1.632 ━━━━━━━━━━━━━━━━━━━━ 4:36 4s/step - accuracy: 0.1936 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:32 4s/step - accuracy: 0.1933 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:28 4s/step - accuracy: 0.1928 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:25 4s/step - accuracy: 0.1925 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:21 4s/step - accuracy: 0.1925 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:17 4s/step - accuracy: 0.1926 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:13 4s/step - accuracy: 0.1927 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:08 4s/step - accuracy: 0.1929 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:06 4s/step - accuracy: 0.1931 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 4:02 4s/step - accuracy: 0.1934 - loss: 1.631 ━━━━━━━━━━━━━━━━━━━━ 3:58 4s/step - accuracy: 0.1938 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 3:54 4s/step - accuracy: 0.1941 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 3:50 4s/step - accuracy: 0.1947 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - accuracy: 0.1951 - loss: 1.630 ━━━━━━━━━━━━━━━━━━━━ 3:42 4s/step - accuracy: 0.1956 - loss: 1.629 ━━━━━━━━━━━━━━━━━━━━ 3:38 4s/step - accuracy: 0.1960 - loss: 1.629 ━━━━━━━━━━━━━━━━━━━━ 3:35 4s/step - accuracy: 0.1964 - loss: 1.629 ━━━━━━━━━━━━━━━━━━━━ 3:32 4s/step - accuracy: 0.1969 - loss: 1.629 ━━━━━━━━━━━━━━━━━━━━ 3:27 4s/step - accuracy: 0.1975 - loss: 1.629 ━━━━━━━━━━━━━━━━━━━━ 3:23 4s/step - accuracy: 0.1980 - loss: 1.628 ━━━━━━━━━━━━━━━━━━━━ 3:19 4s/step - accuracy: 0.1986 - loss: 1.628 ━━━━━━━━━━━━━━━━━━━━ 3:15 4s/step - accuracy: 0.1991 - loss: 1.628 ━━━━━━━━━━━━━━━━━━━━ 3:11 4s/step - accuracy: 0.1996 - loss: 1.628 ━━━━━━━━━━━━━━━━━━━━ 3:07 4s/step - accuracy: 0.2002 - loss: 1.628 ━━━━━━━━━━━━━━━━━━━━ 3:03 4s/step - accuracy: 0.2007 - loss: 1.627 ━━━━━━━━━━━━━━━━━━━━ 2:59 4s/step - accuracy: 0.2013 - loss: 1.627 ━━━━━━━━━━━━━━━━━━━━ 2:55 4s/step - accuracy: 0.2018 - loss: 1.627 ━━━━━━━━━━━━━━━━━━━━ 2:51 4s/step - accuracy: 0.2023 - loss: 1.627 ━━━━━━━━━━━━━━━━━━━━ 2:47 4s/step - accuracy: 0.2028 - loss: 1.627 ━━━━━━━━━━━━━━━━━━━━ 2:43 4s/step - accuracy: 0.2033 - loss: 1.626 ━━━━━━━━━━━━━━━━━━━━ 2:39 4s/step - accuracy: 0.2038 - loss: 1.626 ━━━━━━━━━━━━━━━━━━━━ 2:36 4s/step - accuracy: 0.2043 - loss: 1.626 ━━━━━━━━━━━━━━━━━━━━ 2:32 4s/step - accuracy: 0.2048 - loss: 1.626 ━━━━━━━━━━━━━━━━━━━━ 2:28 4s/step - accuracy: 0.2053 - loss: 1.626 ━━━━━━━━━━━━━━━━━━━━ 2:24 4s/step - accuracy: 0.2057 - loss: 1.625 ━━━━━━━━━━━━━━━━━━━━ 2:20 4s/step - accuracy: 0.2062 - loss: 1.625 ━━━━━━━━━━━━━━━━━━━━ 2:17 4s/step - accuracy: 0.2067 - loss: 1.625 ━━━━━━━━━━━━━━━━━━━━ 2:13 4s/step - accuracy: 0.2071 - loss: 1.625 ━━━━━━━━━━━━━━━━━━━━ 2:09 4s/step - accuracy: 0.2077 - loss: 1.624 ━━━━━━━━━━━━━━━━━━━━ 2:05 4s/step - a ...
# Epoch 2/5
# 63/92 ━━━━━━━━━━━━━━━━━━━━ 6:08 4s/step - accuracy: 0.5000 - loss: 1.522 ━━━━━━━━━━━━━━━━━━━━ 6:08 4s/step - accuracy: 0.5078 - loss: 1.520 ━━━━━━━━━━━━━━━━━━━━ 6:20 4s/step - accuracy: 0.5052 - loss: 1.523 ━━━━━━━━━━━━━━━━━━━━ 5:58 4s/step - accuracy: 0.4961 - loss: 1.525 ━━━━━━━━━━━━━━━━━━━━ 5:48 4s/step - accuracy: 0.4881 - loss: 1.526 ━━━━━━━━━━━━━━━━━━━━ 5:39 4s/step - accuracy: 0.4780 - loss: 1.528 ━━━━━━━━━━━━━━━━━━━━ 5:33 4s/step - accuracy: 0.4703 - loss: 1.529 ━━━━━━━━━━━━━━━━━━━━ 5:28 4s/step - accuracy: 0.4627 - loss: 1.530 ━━━━━━━━━━━━━━━━━━━━ 5:21 4s/step - accuracy: 0.4557 - loss: 1.531 ━━━━━━━━━━━━━━━━━━━━ 5:16 4s/step - accuracy: 0.4495 - loss: 1.532 ━━━━━━━━━━━━━━━━━━━━ 5:11 4s/step - accuracy: 0.4443 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 5:07 4s/step - accuracy: 0.4405 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 5:02 4s/step - accuracy: 0.4371 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 4:58 4s/step - accuracy: 0.4342 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 4:54 4s/step - accuracy: 0.4317 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 4:49 4s/step - accuracy: 0.4291 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:45 4s/step - accuracy: 0.4269 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:41 4s/step - accuracy: 0.4247 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:37 4s/step - accuracy: 0.4228 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:33 4s/step - accuracy: 0.4212 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:30 4s/step - accuracy: 0.4199 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:27 4s/step - accuracy: 0.4186 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:23 4s/step - accuracy: 0.4171 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:20 4s/step - accuracy: 0.4158 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:16 4s/step - accuracy: 0.4149 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:13 4s/step - accuracy: 0.4142 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:10 4s/step - accuracy: 0.4134 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:06 4s/step - accuracy: 0.4129 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 4:03 4s/step - accuracy: 0.4124 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 3:59 4s/step - accuracy: 0.4120 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 3:55 4s/step - accuracy: 0.4117 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 3:51 4s/step - accuracy: 0.4114 - loss: 1.535 ━━━━━━━━━━━━━━━━━━━━ 3:46 4s/step - accuracy: 0.4111 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 3:42 4s/step - accuracy: 0.4108 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 3:38 4s/step - accuracy: 0.4105 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 3:34 4s/step - accuracy: 0.4102 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 3:31 4s/step - accuracy: 0.4100 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 3:27 4s/step - accuracy: 0.4098 - loss: 1.534 ━━━━━━━━━━━━━━━━━━━━ 3:24 4s/step - accuracy: 0.4098 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 3:20 4s/step - accuracy: 0.4098 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 3:17 4s/step - accuracy: 0.4098 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 3:13 4s/step - accuracy: 0.4099 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 3:09 4s/step - accuracy: 0.4099 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 3:05 4s/step - accuracy: 0.4100 - loss: 1.533 ━━━━━━━━━━━━━━━━━━━━ 3:02 4s/step - accuracy: 0.4101 - loss: 1.532 ━━━━━━━━━━━━━━━━━━━━ 2:59 4s/step - accuracy: 0.4102 - loss: 1.532 ━━━━━━━━━━━━━━━━━━━━ 2:55 4s/step - accuracy: 0.4103 - loss: 1.532 ━━━━━━━━━━━━━━━━━━━━ 2:51 4s/step - accuracy: 0.4105 - loss: 1.532 ━━━━━━━━━━━━━━━━━━━━ 2:47 4s/step - accuracy: 0.4107 - loss: 1.532 ━━━━━━━━━━━━━━━━━━━━ 2:43 4s/step - accuracy: 0.4109 - loss: 1.531 ━━━━━━━━━━━━━━━━━━━━ 2:40 4s/step - accuracy: 0.4111 - loss: 1.531 ━━━━━━━━━━━━━━━━━━━━ 2:36 4s/step - accuracy: 0.4113 - loss: 1.531 ━━━━━━━━━━━━━━━━━━━━ 2:32 4s/step - accuracy: 0.4114 - loss: 1.531 ━━━━━━━━━━━━━━━━━━━━ 2:28 4s/step - accuracy: 0.4116 - loss: 1.531 ━━━━━━━━━━━━━━━━━━━━ 2:24 4s/step - accuracy: 0.4118 - loss: 1.530 ━━━━━━━━━━━━━━━━━━━━ 2:21 4s/step - accuracy: 0.4120 - loss: 1.530 ━━━━━━━━━━━━━━━━━━━━ 2:17 4s/step - accuracy: 0.4122 - loss: 1.530 ━━━━━━━━━━━━━━━━━━━━ 2:13 4s/step - accuracy: 0.4124 - loss: 1.530 ━━━━━━━━━━━━━━━━━━━━ 2:09 4s/step - accuracy: 0.4127 - loss: 1.530 ━━━━━━━━━━━━━━━━━━━━ 2:05 4s/step - accur ...

# %% [markdown]
# # 요약 / Summary
# **[KOR]** 위 노트북을 통해 전통적인 CNN과 사전 학습된 ViT 기반 모델을 모두 학습해보고, W&B의 Sweep 기능으로 아키텍처 및 하이퍼파라미터를 자동 탐색할 수 있습니다.
# **[ENG]** This notebook allows you to train both a traditional CNN and a pretrained ViT model, and use W&B Sweeps to automatically search for optimal architectures and hyperparameters.

# %% [markdown]
# # cnn_model 과 vit_model 성능 비교 시각화

# %%
import matplotlib.pyplot as plt
# 성능 비교를 위한 데이터 수집 / Collect data for performance comparison
# CNN과 ViT 모델의 train 및 validation 정확도 및 손실 수집 / Collect train and validation accuracy and loss for CNN and ViT models
cnn_train_accuracies = [0.25, 0.40, 0.53]  # 업데이트된 데이터 / Updated data
vit_train_accuracies = [0.86, 0.88, 0.89, 0.91, 0.92]  # 예시 데이터 / Example data

cnn_val_accuracies = [0.3460, 0.3706, 0.4005]  # 업데이트된 데이터 / Updated data
vit_val_accuracies = [0.83, 0.85, 0.86, 0.88, 0.89]  # 예시 데이터 / Example data

cnn_train_losses = [1.607, 1.478, 1.14]  # 업데이트된 데이터 / Updated data
vit_train_losses = [0.38, 0.34, 0.29, 0.24, 0.19]  # 예시 데이터 / Example data

cnn_val_losses = [1.5462, 1.3370, 1.2600]  # 업데이트된 데이터 / Updated data
vit_val_losses = [0.43, 0.39, 0.34, 0.29, 0.24]  # 예시 데이터 / Example data

# 성능 비교 시각화 / Visualize performance comparison
fig, axs = plt.subplots(2, 2, figsize=(12, 12))

# Train Accuracy
axs[0, 0].plot(cnn_train_accuracies, label='CNN Train Accuracy')
axs[0, 0].plot(vit_train_accuracies, label='ViT Train Accuracy')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Accuracy')
axs[0, 0].set_title('Train Accuracy')
axs[0, 0].legend()

# Train Loss
axs[0, 1].plot(cnn_train_losses, label='CNN Train Loss')
axs[0, 1].plot(vit_train_losses, label='ViT Train Loss')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].set_title('Train Loss')
axs[0, 1].legend()

# Validation Accuracy
axs[1, 0].plot(cnn_val_accuracies, label='CNN Validation Accuracy')
axs[1, 0].plot(vit_val_accuracies, label='ViT Validation Accuracy')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Accuracy')
axs[1, 0].set_title('Validation Accuracy')
axs[1, 0].legend()

# Validation Loss
axs[1, 1].plot(cnn_val_losses, label='CNN Validation Loss')
axs[1, 1].plot(vit_val_losses, label='ViT Validation Loss')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].set_title('Validation Loss')
axs[1, 1].legend()

plt.tight_layout()
plt.show()
